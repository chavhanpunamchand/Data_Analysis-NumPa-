# %%
# %matplotlib inline

from matplotlib import pyplot as plt
plt.plot([1,2,3],[6,9,8])
plt.show()

# %%
# %matplotlib inline

from matplotlib import pyplot as plt
plt.plot([1,2,3],[6,9,8])
plt.title("PC Data")
plt.ylabel("This is Y")
plt.xlabel("This is x")
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
x=[1,5,3]
y=[23,25,87]
x2=[3,8,5]
y2=[27,28,90]
plt.plot(x,y,label="first",linewidth=3)
plt.plot(x2,y2,label="second")
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
x=[1,5,3]
y=[23,25,87]
x2=[3,8,5]
y2=[27,28,90]
plt.scatter(x,y,label="first",linewidth=3)
plt.scatter(x2,y2,label="second")
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
x=[1,5,3]
y=[23,25,87]
x2=[3,8,5]
y2=[27,28,90]
plt.scatter(x,y,label="first",linewidth=3)
plt.hist(x2,label="second")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 5
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# example data
mu = 100 # mean of distribution
sigma = 15 # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

num_bins = 20
# the histogram of the data
n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor='blue', alpha=0.5)

# add a 'best fit' line
y = mlab.normpdf(bins, mu, sigma)
plt.plot(bins, y, 'r--')
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-ad03fc394851> in <module>
#      10 num_bins = 20
#      11 # the histogram of the data
# ---> 12 n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor='blue', alpha=0.5)
#      13
#      14 # add a 'best fit' line
#
# c:\users\punamchand\appdata\local\programs\python\python38\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2666         orientation='vertical', rwidth=None, log=False, color=None,
#    2667         label=None, stacked=False, *, data=None, **kwargs):
# -> 2668     return gca().hist(
#    2669         x, bins=bins, range=range, density=density, weights=weights,
#    2670         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# c:\users\punamchand\appdata\local\programs\python\python38\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1429     def inner(ax, *args, data=None, **kwargs):
#    1430         if data is None:
# -> 1431             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1432
#    1433         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\punamchand\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6791             if patch:
#    6792                 p = patch[0]
# -> 6793                 p.update(kwargs)
#    6794                 if lbl is not None:
#    6795                     p.set_label(lbl)
#
# c:\users\punamchand\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'normed'
