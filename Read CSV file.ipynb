# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#         Symbol       Open       High        Low Last Traded Price  Change  \
# 0     NIFTY 50  11,057.55  11,058.05  10,882.25         10,891.60 -181.85
# 1   TATAMOTORS     103.00     114.40     102.90            111.70    7.05
# 2        TITAN   1,047.00   1,094.65   1,043.00          1,077.25   38.00
# 3    TATASTEEL     364.75     376.85     362.05            371.95    5.65
# 4    EICHERMOT  20,725.00  21,294.00  20,653.20         20,865.30  226.60
# 5         BPCL     414.00     428.25     408.15            416.95    3.15
# 6           LT     913.00     919.75     903.55            917.95    4.50
# 7         SBIN     192.00     194.60     190.05            192.30    0.85
# 8      HCLTECH     709.10     718.00     700.55            707.70    2.50
# 9      DRREDDY   4,521.05   4,670.00   4,500.00          4,530.70    9.65
# 10       WIPRO     283.00     284.80     279.50            281.40    0.45
# 11    SHREECEM  21,670.05  21,864.05  21,490.00         21,745.00   33.85
# ...

# %%
df.head()
# Out:
#        Symbol       Open       High        Low Last Traded Price  Change  \
# 0    NIFTY 50  11,057.55  11,058.05  10,882.25         10,891.60 -181.85
# 1  TATAMOTORS     103.00     114.40     102.90            111.70    7.05
# 2       TITAN   1,047.00   1,094.65   1,043.00          1,077.25   38.00
# 3   TATASTEEL     364.75     376.85     362.05            371.95    5.65
# 4   EICHERMOT  20,725.00  21,294.00  20,653.20         20,865.30  226.60
#
#    %Change Traded Volume(lacs) Traded Value(crs) 52 Week High 52 Week Low  \
# 0    -1.64            6,809.31         31,149.56    12,430.50    7,511.10
# 1     6.74            1,947.66          2,165.80       201.70       63.50
# 2     3.66               76.47            824.62     1,389.95      720.90
# 3     1.54              111.38            414.08       506.00      250.85
# 4     1.10                2.02            421.82    23,450.00   12,450.10
#
#    365 Days % Change  30 Days % Change
# 0              -0.81              4.43
# ...

# %%
print(df['Symbol'].dtype)
# Out:
# object

# %%
print(df['Low'].dtype)
# Out:
# object

# %%
print(df['Change'])
# Out:
# 0    -181.85
# 1       7.05
# 2      38.00
# 3       5.65
# 4     226.60
# 5       3.15
# 6       4.50
# 7       0.85
# 8       2.50
# 9       9.65
# 10      0.45
# 11     33.85
# 12     17.80
# 13      0.35
# 14     -5.40
# 15     -0.75
# 16     -0.55
# 17     -0.80
# 18     -1.20
# 19    -10.90
# 20     -2.20
# 21     -3.05
# 22     -1.85
# 23     -7.15
# 24    -10.70
# 25    -43.60
# 26     -6.75
# 27     -2.00
# 28     -9.00
# 29    -32.40
# 30    -90.75
# 31     -9.45
# 32   -100.65
# 33    -44.35
# 34     -1.60
# 35    -78.30
# 36    -10.90
# 37    -37.95
# 38    -79.10
# 39    -77.85
# 40    -26.90
# 41     -3.75
# 42     -2.70
# 43    -59.45
# 44    -12.65
# 45     -2.55
# 46     -2.95
# 47    -48.75
# 48    -23.20
# 49    -19.60
# 50    -25.65
# Name: Change, dtype: float64
